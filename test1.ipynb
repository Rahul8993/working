# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D

# %%
m = np.random.random_integers(10,70,1000)
print m

#print c
x = np.random.normal(0,1.0,1000)  #for getting normal values in random number generation ( here 0 and 1 are the mean
c=np.mean(x)
d=np.var(x)
e=np.std(x)
print d
print c
print e
#print x
plt.hist(x)
plt.show()
# Out:
# [36 20 45 59 34 12 58 67 44 18 68 61 68 63 63 63 16 42 39 19 49 67 20 24 21
#  43 43 38 39 10 32 21 66 66 25 49 41 39 40 67 60 63 42 52 37 65 56 10 13 66
#  22 38 21 58 32 38 30 24 48 53 21 33 40 47 54 21 51 12 39 51 52 38 61 16 21
#  17 57 15 57 33 32 36 52 25 24 50 49 37 20 14 70 26 27 35 26 44 56 57 18 34
#  64 26 28 50 38 60 69 33 35 46 31 40 39 26 35 60 11 46 55 54 38 10 39 57 20
#  20 18 37 52 40 47 56 27 70 49 12 51 68 70 60 44 38 62 38 31 20 64 37 27 26
#  11 53 34 31 41 41 65 30 30 63 26 36 55 24 12 70 10 48 28 59 26 24 63 20 41
#  48 36 16 28 51 50 35 65 11 60 23 68 35 63 27 22 26 57 66 68 70 22 24 43 15
#  64 17 44 16 23 36 24 31 18 38 67 33 10 30 29 56 63 49 39 43 56 60 68 48 55
#  20 43 49 51 30 31 59 20 62 65 32 44 41 17 10 35 51 59 55 59 66 55 70 45 15
#  23 30 51 56 39 52 43 60 10 48 27 69 11 38 39 55 49 34 59 38 49 56 58 30 23
#  44 68 48 17 57 33 22 51 40 13 60 57 54 65 54 53 11 67 44 49 42 13 69 23 63
# ...

# %%
def fun1(var1,var2):

    print "the value in the function is %d" %var1 
    print "the value in the function is %d" %var2
fun1(20, 20)
# Out:
# the value in the function is 20
# the value in the function is 20

# %%
ize = 1000 

def sig(M):
    return 1/(1+np.exp(-M))

#M = np.zeros(size)

#for i in range(len(x)):
#    M[i] = sig(x[i])

M = [sig(i) for i in x]

#arr = np.array([M])

#np.savetxt('/tmp/out', arr, fmt='%.14f')
plt.scatter(x, M)
plt.show()

# %%
from sys import argv

script = argv[0]
filename = argv[1]

txt = open("rs1.txt")

print "Here's your file %r:" % filename
print txt.read()

print "Type the filename again:"
file_again = raw_input("> ")

txt_again = open(file_again)

print txt_again.read()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-7-f9348d73aef6> in <module>()
#       4 filename = argv[1]
#       5
# ----> 6 txt = open("rs1.txt")
#       7
#       8 print "Here's your file %r:" % filename
#
# IOError: [Errno 2] No such file or directory: 'rs1.txt'

# %%
c=[1,12,2,31,11,22,1]

for j in c:
    print j
# Out:
# 1
# 12
# 2
# 31
# 11
# 22
# 1

# %%
import itertools

c = itertools.count()

for i in itertools.islice(c, 10):
     d=[i]
print d
# Out:
#   File "<ipython-input-63-26ced104b86a>", line 6
#     d=[:,i]
#        ^
# SyntaxError: invalid syntax

# %%
from openpyxl import 

wb = rs2()

# grab the active worksheet
ws = wb.active

# Data can be assigned directly to cells
ws['A1'] = 42

# Rows can also be appended
ws.append([1, 2, 3])

# Python types will automatically be converted
import datetime
ws['A2'] = datetime.datetime.now()

# Save the file
wb.save("sample.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-18-6e024579a4c3> in <module>()
# ----> 1 from openpyxl import rs2
#       2
#       3 wb = rs2()
#       4
#       5 # grab the active worksheet
#
# ImportError: cannot import name rs2

# %%
 gamaa=77
def grad():
    alpha=(0.5-1)
    beta=1
    print alpha
    print beta
   # gamaa=77
    lemda=alpha-beta+100+gamaa
    print "lemda",lemda 
    return lemda
grad()

def grad1():
    
    out=grad()
    
    print out
    
    print gamaa
    
    
    
grad1()
# Out:
# -0.5
# 1
# lemda 175.5
# -0.5
# 1
# lemda 175.5
# 175.5
# 77

# %%
print "a"
# Out:
# a

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# %%
def add(a, b):
    print "ADDING %d + %d" % (a, b)
    return a + b

def subtract(a, b):
    print "SUBTRACTING %d - %d" % (a, b)
    return a - b

def multiply(a, b):
    print "MULTIPLYING %d * %d" % (a, b)
    return a * b

def divide(a, b):
    print "DIVIDING %d / %d" % (a, b)
    return a / b


print "Let's do some math with just functions!"

age = add(30, 5)
height = subtract(78, 4)
weight = multiply(90, 2)
iq = divide(100, 2)

print "Age: %d, Height: %d, Weight: %d, IQ: %d" % (age, height, weight, iq)


# A puzzle for the extra credit, type it in anyway.
print "Here is a puzzle."

what = add(age, subtract(height, multiply(weight, divide(iq, 2))))

print "That becomes: ", what, "Can you do it by hand?"
# Out:
# Let's do some math with just functions!
# ADDING 30 + 5
# SUBTRACTING 78 - 4
# MULTIPLYING 90 * 2
# DIVIDING 100 / 2
# Age: 35, Height: 74, Weight: 180, IQ: 50
# Here is a puzzle.
# DIVIDING 50 / 2
# MULTIPLYING 180 * 25
# SUBTRACTING 74 - 4500
# ADDING 35 + -4426
# That becomes:  -4391 Can you do it by hand?

# %%
def add():
    
    a=1
    b=1
    add1=a+b
    
    return add1

add()

def sub():
    a=1
    b=1
    sub1=a-b
    return sub1
sub()

def mul():
    a=1
    b=1
    mul1=a*b
    return mul1

mul()

def cal():
    out1=add()
    
    
    out2=sub()
    print out2
    print out1
     

cal()
# Out:
# 0
# 2

# %%
import numpy as np
import random
from sklearn.datasets.samples_generator import make_regression 
import pylab
from scipy import stats

def gradient_descent_2(alpha, x, y, numIterations):
    m = x.shape[0] # number of samples
    theta = np.ones(2)
    x_transpose = x.transpose()
    for iter in range(0, numIterations):
        hypothesis = np.dot(x, theta)
        loss = hypothesis - y
        J = np.sum(loss ** 2) / (2 * m)  # cost
        print "iter %s | J: %.3f" % (iter, J)      
        gradient = np.dot(x_transpose, loss) / m         
        theta = theta - alpha * gradient  # update
    return theta

if __name__ == '__main__':

    x, y = make_regression(n_samples=100, n_features=1, n_informative=1, 
                        random_state=0, noise=35) 
    m, n = np.shape(x)
    x = np.c_[ np.ones(m), x] # insert column
    alpha = 0.01 # learning rate
    theta = gradient_descent_2(alpha, x, y, 1000)

    # plot
    for i in range(x.shape[1]):
        y_predict = theta[0] + theta[1]*x 
    pylab.plot(x[:,1],y,'o')
    pylab.plot(x,y_predict,'k-')
    pylab.show()
    plt.colorbar()
    print "Done!"
# Out:
# iter 0 | J: 1604.873
# iter 1 | J: 1586.636
# iter 2 | J: 1568.768
# iter 3 | J: 1551.261
# iter 4 | J: 1534.107
# iter 5 | J: 1517.301
# iter 6 | J: 1500.833
# iter 7 | J: 1484.699
# iter 8 | J: 1468.890
# iter 9 | J: 1453.401
# iter 10 | J: 1438.224
# iter 11 | J: 1423.354
# iter 12 | J: 1408.785
# iter 13 | J: 1394.509
# iter 14 | J: 1380.522
# iter 15 | J: 1366.817
# iter 16 | J: 1353.389
# iter 17 | J: 1340.232
# iter 18 | J: 1327.341
# iter 19 | J: 1314.710
# iter 20 | J: 1302.334
# iter 21 | J: 1290.207
# iter 22 | J: 1278.325
# iter 23 | J: 1266.683
# iter 24 | J: 1255.276
# iter 25 | J: 1244.100
# iter 26 | J: 1233.148
# iter 27 | J: 1222.418
# iter 28 | J: 1211.904
# iter 29 | J: 1201.602
# iter 30 | J: 1191.507
# iter 31 | J: 1181.617
# iter 32 | J: 1171.926
# iter 33 | J: 1162.430
# iter 34 | J: 1153.126
# iter 35 | J: 1144.009
# iter 36 | J: 1135.076
# iter 37 | J: 1126.323
# iter 38 | J: 1117.747
# iter 39 | J: 1109.343
# iter 40 | J: 1101.109
# iter 41 | J: 1093.041
# ...
